# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('data_academic_performance.xlsx')

# %%
df.isna().sum()
# Out:
# COD_S11                 0
# GENDER                  0
# EDU_FATHER              0
# EDU_MOTHER              0
# OCC_FATHER              0
# OCC_MOTHER              0
# STRATUM                 0
# SISBEN                  0
# PEOPLE_HOUSE            0
# Unnamed: 9          12411
# INTERNET                0
# TV                      0
# COMPUTER                0
# WASHING_MCH             0
# MIC_OVEN                0
# CAR                     0
# DVD                     0
# FRESH                   0
# PHONE                   0
# MOBILE                  0
# REVENUE                 0
# JOB                     0
# SCHOOL_NAME             0
# SCHOOL_NAT              0
# SCHOOL_TYPE             0
# MAT_S11                 0
# CR_S11                  0
# CC_S11                  0
# BIO_S11                 0
# ENG_S11                 0
# Cod_SPro                0
# UNIVERSITY              0
# ACADEMIC_PROGRAM        0
# QR_PRO                  0
# CR_PRO                  0
# CC_PRO                  0
# ENG_PRO                 0
# WC_PRO                  0
# FEP_PRO                 0
# G_SC                    0
# PERCENTILE              0
# 2ND_DECILE              0
# QUARTILE                0
# SEL                     0
# SEL_IHE                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#                 COD_S11 GENDER                       EDU_FATHER  \
# 4192   SB11201220579114      F                                0
# 11557  SB11201420018867      F             Incomplete Secundary
# 1538   SB11201220207008      M              Incomplete primary
# 8808   SB11201320287707      F              Incomplete primary
# 12129  SB11201420307972      M  Complete professional education
# 10044  SB11201320427814      F                         Not sure
# 3113   SB11201220392856      M  Complete professional education
# 10644  SB11201320505627      M           Postgraduate education
# 7200   SB11201320161422      F           Postgraduate education
# 50     SB11201210037275      F  Complete professional education
#
#                               EDU_MOTHER  \
# 4192                                   0
# 11557               Incomplete Secundary
# 1538                   Complete primary
# 8808                 Incomplete primary
# 12129    Complete professional education
# 10044             Postgraduate education
# 3113     Complete professional education
# 10644                  Complete primary
# 7200     Complete professional education
# 50     Incomplete Professional Education
#
#                                      OCC_FATHER  \
# 4192                                          0
# 11557                               Independent
# 1538                        Small entrepreneur
# 8808                                Independent
# 12129  Technical or professional level employee
# 10044                                   Retired
# 3113                   Independent professional
# 10644                  Independent professional
# 7200                                  Executive
# 50                     Independent professional
#
#                                      OCC_MOTHER    STRATUM  \
# 4192                                       Home  Stratum 2
# 11557                               Independent  Stratum 4
# 1538                        Small entrepreneur   Stratum 1
# 8808                                       Home  Stratum 1
# 12129  Technical or professional level employee  Stratum 3
# 10044                                 Executive  Stratum 4
# 3113                                  Executive  Stratum 3
# 10644                                      Home  Stratum 3
# 7200                Auxiliary or Administrative  Stratum 3
# 50                     Independent professional  Stratum 6
#
#                                    SISBEN PEOPLE_HOUSE  Unnamed: 9  ...  \
# 4192   It is not classified by the SISBEN         Four         NaN  ...
# 11557  It is not classified by the SISBEN         Four         NaN  ...
# 1538                              Level 1          Two         NaN  ...
# 8808                              Level 2        Three         NaN  ...
# 12129  It is not classified by the SISBEN        Three         NaN  ...
# 10044  It is not classified by the SISBEN         Four         NaN  ...
# 3113   It is not classified by the SISBEN         Four         NaN  ...
# 10644  It is not classified by the SISBEN          Six         NaN  ...
# 7200   It is not classified by the SISBEN         Five         NaN  ...
# 50     It is not classified by the SISBEN         Four         NaN  ...
#
#       CC_PRO ENG_PRO WC_PRO FEP_PRO G_SC PERCENTILE 2ND_DECILE QUARTILE SEL  \
# 4192      63      62     17     124  143         45          3        2   2
# 11557     13      11     19     119  113          6          1        1   2
# 1538      49      13     41     157  151         58          3        3   1
# 8808      35      57     67      92  151         58          3        3   2
# 12129     86      70     76      70  189         96          5        4   4
# 10044     83      88     34     199  169         82          5        4   4
# 3113       7      23      4     160  129         22          2        1   4
# 10644     96      31     11     176  157         67          4        3   4
# 7200      93      83     68     178  194         97          5        4   4
# 50        15      73     78      85  139         39          2        2   4
#
#       SEL_IHE
# 4192        2
# 11557       2
# 1538        2
# 8808        4
# 12129       3
# 10044       4
# 3113        1
# 10644       2
# 7200        2
# 50          2
#
# [10 rows x 45 columns]

# %%
df.drop(columns=['Unnamed: 9'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12411 entries, 0 to 12410
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   COD_S11           12411 non-null  object
#  1   GENDER            12411 non-null  object
#  2   EDU_FATHER        12411 non-null  object
#  3   EDU_MOTHER        12411 non-null  object
#  4   OCC_FATHER        12411 non-null  object
#  5   OCC_MOTHER        12411 non-null  object
#  6   STRATUM           12411 non-null  object
#  7   SISBEN            12411 non-null  object
#  8   PEOPLE_HOUSE      12411 non-null  object
#  9   INTERNET          12411 non-null  object
#  10  TV                12411 non-null  object
#  11  COMPUTER          12411 non-null  object
#  12  WASHING_MCH       12411 non-null  object
#  13  MIC_OVEN          12411 non-null  object
#  14  CAR               12411 non-null  object
#  15  DVD               12411 non-null  object
#  16  FRESH             12411 non-null  object
#  17  PHONE             12411 non-null  object
#  18  MOBILE            12411 non-null  object
#  19  REVENUE           12411 non-null  object
#  20  JOB               12411 non-null  object
#  21  SCHOOL_NAME       12411 non-null  object
#  22  SCHOOL_NAT        12411 non-null  object
#  23  SCHOOL_TYPE       12411 non-null  object
#  24  MAT_S11           12411 non-null  int64
#  25  CR_S11            12411 non-null  int64
#  26  CC_S11            12411 non-null  int64
#  27  BIO_S11           12411 non-null  int64
#  28  ENG_S11           12411 non-null  int64
#  29  Cod_SPro          12411 non-null  object
#  30  UNIVERSITY        12411 non-null  object
#  31  ACADEMIC_PROGRAM  12411 non-null  object
#  32  QR_PRO            12411 non-null  int64
#  33  CR_PRO            12411 non-null  int64
#  34  CC_PRO            12411 non-null  int64
#  35  ENG_PRO           12411 non-null  int64
#  36  WC_PRO            12411 non-null  int64
#  37  FEP_PRO           12411 non-null  int64
#  38  G_SC              12411 non-null  int64
#  39  PERCENTILE        12411 non-null  int64
#  40  2ND_DECILE        12411 non-null  int64
#  41  QUARTILE          12411 non-null  int64
#  42  SEL               12411 non-null  int64
#  43  SEL_IHE           12411 non-null  int64
# dtypes: int64(17), object(27)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#             MAT_S11        CR_S11        CC_S11       BIO_S11       ENG_S11  \
# count  12411.000000  12411.000000  12411.000000  12411.000000  12411.000000
# mean      64.320764     60.778422     60.705181     63.950528     61.801064
# std       11.873650     10.025876     10.120524     11.156869     14.297777
# min       26.000000     24.000000      0.000000     11.000000     26.000000
# 25%       56.000000     54.000000     54.000000     56.000000     50.000000
# 50%       64.000000     61.000000     60.000000     64.000000     59.000000
# 75%       72.000000     67.000000     67.000000     71.000000     72.000000
# max      100.000000    100.000000    100.000000    100.000000    100.000000
#
#              QR_PRO        CR_PRO       CC_PRO       ENG_PRO        WC_PRO  \
# count  12411.000000  12411.000000  12411.00000  12411.000000  12411.000000
# mean      77.417291     62.199339     59.18677     67.498348     53.703408
# std       22.673444     27.666558     28.99184     25.495096     30.001734
# min        1.000000      1.000000      1.00000      1.000000      0.000000
# 25%       65.000000     42.000000     36.00000     51.000000     28.000000
# 50%       85.000000     67.000000     65.00000     74.000000     56.000000
# 75%       96.000000     86.000000     85.00000     88.000000     80.000000
# max      100.000000    100.000000    100.00000    100.000000    100.000000
#
#             FEP_PRO          G_SC    PERCENTILE    2ND_DECILE      QUARTILE  \
# count  12411.000000  12411.000000  12411.000000  12411.000000  12411.000000
# mean     145.476593    162.710499     68.446459      3.885747      3.188865
# std       40.126386     23.112479     25.867550      1.248431      0.979043
# min        1.000000     37.000000      1.000000      1.000000      1.000000
# 25%      124.000000    147.000000     51.000000      3.000000      3.000000
# 50%      153.000000    163.000000     75.000000      4.000000      4.000000
# 75%      174.000000    179.000000     90.000000      5.000000      4.000000
# max      300.000000    247.000000    100.000000      5.000000      4.000000
#
#                 SEL       SEL_IHE
# count  12411.000000  12411.000000
# mean       2.598904      2.409395
# std        1.111704      0.926765
# min        1.000000      1.000000
# 25%        2.000000      2.000000
# 50%        2.000000      2.000000
# 75%        4.000000      3.000000
# max        4.000000      4.000000

# %%
df.rename(columns={'MAT_S11': 'Math_S11',
                   'CR_S11': 'Critical Reading_S11', 
                   'CC_S11': 'Citizen Competencies_S11',
                   'BIO_S11': 'Biology_S11', 
                   'ENG_S11': 'English_S11',
                   'QR_PRO': 'Quantitative Reasoning_PRO',
                   'CR_PRO': 'Critical Reading_PRO',
                   'CC_PRO': 'Citizen Competencies_PRO',
                   'ENG_PRO': 'English_PRO',
                   'WC_PRO': 'Written Communication_PRO',
                   'FEP_PRO': 'Formulation of Engineering Projects_PRO',
                   'SEL': 'Socioeconomic Level',
                   'SEL_IHE': 'Socioeconomic Level of The Institution of Higher Education'}, inplace=True)

# %%
def detect_outliers_iqr(df, numeric_columns):
    outlier_indices = []

    for column in numeric_columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)].index
        outlier_indices.extend(outliers)

    return df.loc[list(set(outlier_indices))]

numeric_columns = [
    "Math_S11", "Critical Reading_S11", "Citizen Competencies_S11", "Biology_S11", "English_S11",
    "Quantitative Reasoning_PRO", "Critical Reading_PRO", "Citizen Competencies_PRO", "English_PRO",
    "Written Communication_PRO", "Formulation of Engineering Projects_PRO", "PERCENTILE",
    "2ND_DECILE", "QUARTILE", "Socioeconomic Level",
    "Socioeconomic Level of The Institution of Higher Education"
]

outliers = detect_outliers_iqr(df, numeric_columns)
print("Outliers:")
print(outliers)
# Out:
# Outliers:
#                COD_S11 GENDER                             EDU_FATHER  \
# 1     SB11201210000137      F                     Complete Secundary
# 2     SB11201210005154      M                               Not sure
# 9     SB11201210013577      M  Incomplete technical or technological
# 8201  SB11201320238852      F                     Complete Secundary
# 18    SB11201210024293      M       Complete technique or technology
# ...                ...    ...                                    ...
# 8144  SB11201320234853      M        Complete professional education
# 8145  SB11201320234929      M       Complete technique or technology
# 8160  SB11201320236436      F        Complete professional education
# 8166  SB11201320236767      M                    Incomplete primary
# 8174  SB11201320237288      F                   Incomplete Secundary
#
#                                  EDU_MOTHER  \
# 1           Complete professional education
# 2                                  Not sure
# 9     Incomplete technical or technological
# 8201        Complete professional education
# 18                       Complete Secundary
# ...                                     ...
# 8144        Complete professional education
# 8145                     Complete Secundary
# 8160        Complete professional education
# 8166                                Ninguno
# 8174                    Incomplete primary
#
#                                     OCC_FATHER  \
# 1                                Entrepreneur
# 2                                  Independent
# 9                                  Independent
# 8201                               Independent
# 18                                    Operator
# ...                                        ...
# 8144                             Entrepreneur
# 8145  Technical or professional level employee
# 8160                          Other occupation
# 8166                       Small entrepreneur
# 8174                                  Operator
#
#                                     OCC_MOTHER    STRATUM  \
# 1                     Independent professional  Stratum 5
# 2                                         Home  Stratum 2
# 9                                         Home  Stratum 2
# 8201  Technical or professional level employee  Stratum 2
# 18                                 Independent  Stratum 2
# ...                                        ...        ...
# 8144                                  Operator  Stratum 4
# 8145                                  Operator  Stratum 2
# 8160  Technical or professional level employee  Stratum 5
# 8166                                      Home  Stratum 2
# 8174                                      Home  Stratum 2
#
#                                   SISBEN PEOPLE_HOUSE INTERNET  ...  \
# 1     It is not classified by the SISBEN        Three      Yes  ...
# 2                                Level 2         Five       No  ...
# 9                                Level 2         Four      Yes  ...
# 8201  It is not classified by the SISBEN         Four      Yes  ...
# 18                               Level 2         Four      Yes  ...
# ...                                  ...          ...      ...  ...
# 8144  It is not classified by the SISBEN        Three      Yes  ...
# 8145  It is not classified by the SISBEN         Five      Yes  ...
# 8160  It is not classified by the SISBEN        Three      Yes  ...
# 8166  It is not classified by the SISBEN          Six      Yes  ...
# 8174  It is not classified by the SISBEN         Five       No  ...
#
#      Citizen Competencies_PRO English_PRO Written Communication_PRO  \
# 1                          86          98                        78
# 2                          18          43                        22
# 9                          22          83                         1
# 8201                        3          65                        19
# 18                         12          19                        65
# ...                       ...         ...                       ...
# 8144                       88         100                        85
# 8145                       95          79                        93
# 8160                       97          97                        88
# 8166                       10          16                        52
# 8174                       93          95                        84
#
#      Formulation of Engineering Projects_PRO G_SC PERCENTILE 2ND_DECILE  \
# 1                                        201  182         92          5
# 2                                        113  113          7          1
# 9                                        112  126         18          1
# 8201                                      83  123         15          1
# 18                                       120  129         22          2
# ...                                      ...  ...        ...        ...
# 8144                                     184  201         99          5
# 8145                                      95  193         97          5
# 8160                                     224  201         99          5
# 8166                                     126  128         21          2
# 8174                                      93  195         98          5
#
#      QUARTILE Socioeconomic Level  \
# 1           4                   4
# 2           1                   1
# 9           1                   4
# 8201        1                   4
# 18          1                   2
# ...       ...                 ...
# 8144        4                   3
# 8145        4                   2
# 8160        4                   4
# 8166        1                   2
# 8174        4                   1
#
#      Socioeconomic Level of The Institution of Higher Education
# 1                                                     4
# 2                                                     1
# 9                                                     2
# 8201                                                  2
# 18                                                    1
# ...                                                 ...
# 8144                                                  4
# 8145                                                  2
# 8160                                                  4
# 8166                                                  2
# 8174                                                  2
#
# [1921 rows x 44 columns]

# %%
sns.set(style="whitegrid")

def plot_boxplots(df, numeric_columns):
    num_cols = len(numeric_columns)
    num_rows = (num_cols + 2) // 3 

    plt.figure(figsize=(18, num_rows * 4))

    for i, col in enumerate(numeric_columns, 1):
        plt.subplot(num_rows, 3, i)
        sns.boxplot(data=df, y=col, color="skyblue")
        plt.title(col)
        plt.tight_layout()

    plt.show()

plot_boxplots(df, numeric_columns)

# %%
print(df['EDU_FATHER'].unique())
print(df['EDU_MOTHER'].unique())
print(df['OCC_FATHER'].unique())
print(df['OCC_MOTHER'].unique())

df['EDU_FATHER'] = df['EDU_FATHER'].apply(lambda x: 'Unknown' if str(x).strip().lower() in ['ninguno', '0', 'not sure'] else x)
df['EDU_MOTHER'] = df['EDU_MOTHER'].apply(lambda x: 'Unknown' if str(x).strip().lower() in ['ninguno', '0', 'not sure'] else x)
df['OCC_FATHER'] = df['OCC_FATHER'].apply(lambda x: 'Unknown' if str(x).strip() == '0' else x)
df['OCC_MOTHER'] = df['OCC_MOTHER'].apply(lambda x: 'Unknown' if str(x).strip() == '0' else x)

print(df['EDU_FATHER'].value_counts())
print(df['EDU_MOTHER'].value_counts())
print(df['OCC_FATHER'].value_counts())
print(df['OCC_MOTHER'].value_counts())
# Out:
# ['Incomplete Professional Education' 'Complete Secundary' 'Not sure'
#  'Complete professional education' 'Incomplete Secundary'
#  'Incomplete technical or technological'
#  'Complete technique or technology' 'Incomplete primary '
#  'Complete primary ' 'Postgraduate education' 0 'Ninguno']
# ['Complete technique or technology' 'Complete professional education'
#  'Not sure' 'Complete Secundary' 'Incomplete technical or technological'
#  'Incomplete primary ' 'Incomplete Secundary'
#  'Incomplete Professional Education' 'Postgraduate education'
#  'Complete primary ' 0 'Ninguno']
# ['Technical or professional level employee' 'Entrepreneur ' 'Independent'
#  'Other occupation' 'Executive' 'Small entrepreneur '
#  'Independent professional' 'Operator' 0 'Retired'
#  'Auxiliary or Administrative' 'Home']
# ['Home' 'Independent professional' 'Independent' 'Executive' 'Operator'
#  'Entrepreneur ' 'Small entrepreneur '
#  'Technical or professional level employee' 0
#  'Auxiliary or Administrative' 'Other occupation' 'Retired']
# EDU_FATHER
# Complete professional education          3016
# Complete Secundary                       2843
# Complete technique or technology         1194
# Incomplete Secundary                     1091
# Postgraduate education                   1085
# Unknown                                   921
# Complete primary                          824
# Incomplete primary                        735
# Incomplete Professional Education         425
# Incomplete technical or technological     277
# Name: count, dtype: int64
# EDU_MOTHER
# Complete Secundary                       3106
# Complete professional education          3059
# Complete technique or technology         1495
# Incomplete Secundary                     1056
# Postgraduate education                    997
# Complete primary                          713
# Unknown                                   601
# Incomplete primary                        541
# Incomplete Professional Education         502
# Incomplete technical or technological     341
# Name: count, dtype: int64
# OCC_FATHER
# Independent                                 2907
# Technical or professional level employee    1803
# Operator                                    1537
# Other occupation                            1087
# Executive                                   1077
# Unknown                                      940
# Independent professional                     915
# Small entrepreneur                           692
# Retired                                      532
# Entrepreneur                                 472
# Auxiliary or Administrative                  372
# Home                                          77
# Name: count, dtype: int64
# OCC_MOTHER
# Home                                        4658
# Technical or professional level employee    1795
# Independent                                 1107
# Auxiliary or Administrative                  846
# Executive                                    794
# Independent professional                     715
# Operator                                     684
# Other occupation                             607
# Small entrepreneur                           492
# Unknown                                      313
# Entrepreneur                                 242
# Retired                                      158
# Name: count, dtype: int64

# %%
def get_top_academic_features(df, academic_features, target='G_SC', top_n=6):
    correlations = df[academic_features + [target]].corr()[target].drop(target)
    top_features = correlations.abs().sort_values(ascending=False).head(top_n).index.tolist()
    return top_features

def get_top_socioeconomic_features(df, socioeconomic_features, target='G_SC', top_n=6):
    correlations = df[socioeconomic_features + [target]].corr()[target].drop(target)
    top_features = correlations.abs().sort_values(ascending=False).head(top_n).index.tolist()
    return top_features

# %% [markdown]
# ## Encoding

# %%
df['GENDER'] = df['GENDER'].map({'M': 1, 'F': 0})

# %%
device_columns = ['DVD', 'FRESH', 'PHONE', 'MOBILE', 'CAR','MIC_OVEN','WASHING_MCH','COMPUTER','TV','INTERNET']
for col in device_columns:
    df[col] = df[col].map({'Yes': 1, 'No': 0})
df['Asset Index'] = df[device_columns].sum(axis=1)
df = df.drop(columns=device_columns)

# %%
revenue_mapping = {
    '0': 0,
    'less than 1 LMMW': 1,
    'Between 1 and less than 2 LMMW': 2,
    'Between 2 and less than 3 LMMW': 3,
    'Between 3 and less than 5 LMMW': 4,
    'Between 5 and less than 7 LMMW': 5,
    'Between 7 and less than 10 LMMW': 6,
    '10 or more LMMW': 7
}

# Create a Revenue Index column
df['Revenue'] = df['REVENUE'].map(revenue_mapping)
df = df.drop(columns=['REVENUE'])

# %%
df['STRATUM'] = df['STRATUM'].replace({0: "Unknown"})

numerical_mapping = {
    "Unknown": 0,
    'Stratum 1': 1,
    'Stratum 2': 2,
    'Stratum 3': 3,
    'Stratum 4': 4,
    'Stratum 5': 5,
    'Stratum 6': 6
}
df['STRATUM_NUMERICAL'] = df['STRATUM'].map(numerical_mapping)

df = df.drop(columns=['STRATUM'])

# %%
df = df.drop(columns=['SISBEN'])

# %%
def target_encode(df, feature, target):
    if feature not in df.columns:
        print(f"Feature '{feature}' not found in the DataFrame!")
        return None
    category_means = df.groupby(feature)[target].mean()
    return df[feature].map(category_means)

# Features to encode
features_to_encode = ['OCC_FATHER', 'OCC_MOTHER', 'EDU_FATHER', 'EDU_MOTHER']

# Apply encoding
for feature in features_to_encode:
    if feature in df.columns:
        df[f'{feature}_ENCODED'] = target_encode(df, feature, 'G_SC')
    else:
        print(f"Skipping {feature}: Column not found in DataFrame.")

# Drop original columns if they exist
df = df.drop(columns=[col for col in features_to_encode if col in df.columns], errors='ignore')

# Display the updated DataFrame
print(df.head())
# Out:
#             COD_S11  GENDER PEOPLE_HOUSE                             JOB  \
# 0  SB11201210000129       0        Three                              No
# 1  SB11201210000137       0        Three                              No
# 2  SB11201210005154       1         Five  Yes, 20 hours or more per week
# 3  SB11201210007504       0        Three                              No
# 4  SB11201210007548       1          One                              No
#
#                                          SCHOOL_NAME SCHOOL_NAT SCHOOL_TYPE  \
# 0                                COL NUEVO CAMBRIDGE    PRIVATE    ACADEMIC
# 1                           COL LA QUINTA DEL PUENTE    PRIVATE    ACADEMIC
# 2  CENT EDUC PAULO FREIRE                        ...    PRIVATE    ACADEMIC
# 3                                       LICEO ANDINO    PRIVATE    ACADEMIC
# 4                              LIC TALLER SAN MIGUEL    PRIVATE    ACADEMIC
#
#    Math_S11  Critical Reading_S11  Citizen Competencies_S11  ...  QUARTILE  \
# 0        71                    81                        61  ...         4
# 1        83                    75                        66  ...         4
# 2        52                    49                        38  ...         1
# 3        56                    55                        51  ...         3
# 4        80                    65                        76  ...         4
#
#    Socioeconomic Level  \
# 0                    2
# 1                    4
# 2                    1
# 3                    2
# 4                    4
#
#   Socioeconomic Level of The Institution of Higher Education Asset Index  \
# 0                                                  2                   8
# 1                                                  4                  10
# 2                                                  1                   5
# 3                                                  2                   9
# 4                                                  2                   9
#
#   Revenue  STRATUM_NUMERICAL  OCC_FATHER_ENCODED  OCC_MOTHER_ENCODED  \
# 0     2.0                  4          165.815862          159.929798
# 1     7.0                  5          168.699153          170.184615
# 2     2.0                  2          158.726178          159.929798
# 3     3.0                  2          160.101196          158.951220
# 4     6.0                  4          169.746518          159.929798
#
#    EDU_FATHER_ENCODED  EDU_MOTHER_ENCODED
# 0          166.917647          163.242140
# 1          158.785790          168.845374
# 2          157.590662          155.968386
# 3          157.590662          155.968386
# 4          167.765915          168.845374
#
# [5 rows x 34 columns]

# %%
df['PEOPLE_HOUSE'].value_counts()
# Out:
# PEOPLE_HOUSE
# Four              4767
# Five              2870
# Three             2345
# Six               1090
# Two                592
# Seven              372
# Eight              164
# Nueve               74
# Ten                 52
# Twelve or more      32
# 0                   21
# Once                19
# One                 13
# Name: count, dtype: int64

# %%
df = df[df['PEOPLE_HOUSE'] != '0']

df['PEOPLE_HOUSE'] = df['PEOPLE_HOUSE'].replace({'Nueve': 'Nine'})

df['PEOPLE_HOUSE'] = df['PEOPLE_HOUSE'].replace({'Once': 'One'})

df_one_hot = pd.get_dummies(df['PEOPLE_HOUSE'], prefix='PEOPLE_HOUSE')
df_one_hot = df_one_hot.astype(int)
# Concatenate the one-hot encoded columns with the original DataFrame
df = pd.concat([df, df_one_hot], axis=1)

# Drop the original PEOPLE_HOUSE column
df = df.drop(columns=['PEOPLE_HOUSE'])

# %%
# Drop columns if they exist
columns_to_drop = ['SCHOOL_NAME', 'COD_S11', 'Cod_SPro']
df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# %%
df_one_hot = pd.get_dummies(df['SCHOOL_NAT'], prefix='SCHOOL_NAT')

df_one_hot = df_one_hot.astype(int)

df = pd.concat([df, df_one_hot], axis=1)

df = df.drop(columns=['SCHOOL_NAT'])

# %%
df['SCHOOL_TYPE'].value_counts()
# Out:
# SCHOOL_TYPE
# ACADEMIC              7834
# TECHNICAL/ACADEMIC    3513
# TECHNICAL             1059
# Not apply                5
# Name: count, dtype: int64

# %%
df_one_hot = pd.get_dummies(df['SCHOOL_TYPE'], prefix='SCHOOL_TYPE')


df_one_hot = df_one_hot.astype(int)


df = pd.concat([df, df_one_hot], axis=1)


df = df.drop(columns=['SCHOOL_TYPE'])

# %%
df['JOB'].value_counts()
# Out:
# JOB
# No                                  11909
# Yes, less than 20 hours per week      230
# 0                                     138
# Yes, 20 hours or more per week        134
# Name: count, dtype: int64

# %%
df['JOB'] = df['JOB'].replace({'0': 'No'})

df_one_hot = pd.get_dummies(df['JOB'], prefix='JOB')
df_one_hot = df_one_hot.astype(int) 

df = pd.concat([df, df_one_hot], axis=1)

df = df.drop(columns=['JOB'])

# %%
def target_encode(df, feature, target):
    category_means = df.groupby(feature)[target].mean()
    return df[feature].map(category_means)

df['UNIVERSITY_ENCODED'] = target_encode(df, 'UNIVERSITY', 'G_SC')
df['ACADEMIC_PROGRAM_ENCODED'] = target_encode(df, 'ACADEMIC_PROGRAM', 'G_SC')

# Drop the original columns
df = df.drop(columns=['UNIVERSITY', 'ACADEMIC_PROGRAM'])

# %%
academic_features = [
    'Math_S11', 'Critical Reading_S11', 'Citizen Competencies_S11', 
    'Biology_S11', 'English_S11', 'Quantitative Reasoning_PRO', 
    'Critical Reading_PRO', 'Citizen Competencies_PRO', 'English_PRO',
    'Written Communication_PRO', 'Formulation of Engineering Projects_PRO','UNIVERSITY_ENCODED','ACADEMIC_PROGRAM_ENCODED'
]


socioeconomic_features = [
    'GENDER', 'Asset Index', 'Revenue','STRATUM_NUMERICAL','OCC_FATHER_ENCODED','OCC_MOTHER_ENCODED','EDU_FATHER_ENCODED','EDU_MOTHER_ENCODED',
    'UNIVERSITY_ENCODED','ACADEMIC_PROGRAM_ENCODED', 'PEOPLE_HOUSE_0', 'PEOPLE_HOUSE_One',
    'PEOPLE_HOUSE_Two', 'PEOPLE_HOUSE_Three', 'PEOPLE_HOUSE_Four', 'PEOPLE_HOUSE_Five', 'PEOPLE_HOUSE_Six',
    'PEOPLE_HOUSE_Seven', 'PEOPLE_HOUSE_Eight', 'PEOPLE_HOUSE_Nine', 'PEOPLE_HOUSE_Ten', 'PEOPLE_HOUSE_Twelve or more','SCHOOL_NAT_PUBLIC'
    ,'SCHOOL_NAT_PUBLIC','SCHOOL_TYPE_ACADEMIC','SCHOOL_TYPE_Not apply','SCHOOL_TYPE_TECHNICAL','SCHOOL_TYPE_TECHNICAL/ACADEMIC','JOB_0','JOB_No','JOB_Yes, 20 hours or more per week','JOB_Yes, less than 20 hours per week']


top_academic = get_top_academic_features(df, academic_features)
top_socioeconomic = get_top_socioeconomic_features(df, socioeconomic_features)

print("Top Academic Features:", top_academic)
print("Top Socioeconomic Features:", top_socioeconomic)
# Out:
# Top Academic Features: ['Critical Reading_PRO', 'Citizen Competencies_PRO', 'English_PRO', 'Quantitative Reasoning_PRO', 'Biology_S11', 'English_S11']
# Top Socioeconomic Features: ['UNIVERSITY_ENCODED', 'Revenue', 'STRATUM_NUMERICAL', 'EDU_FATHER_ENCODED', 'EDU_MOTHER_ENCODED', 'SCHOOL_NAT_PUBLIC']

# %%
import numpy as np

class MultipleLinearRegression:
    def __init__(self):
        self.coefficients = None

    def fit(self, X, y):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]  # Add bias
        self.coefficients = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

    def predict(self, X):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]
        return X_b @ self.coefficients

# %%
import matplotlib.pyplot as plt

class ModelEvaluator:
    def __init__(self):
        pass

    def mean_squared_error(self, y_true, y_pred):
        return np.mean((y_true - y_pred) ** 2)

    def r2_score(self, y_true, y_pred):
        ss_res = np.sum((y_true - y_pred) ** 2)
        ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
        return 1 - (ss_res / ss_tot)

    def plot_predictions(self, y_true, y_pred, title='Actual vs Predicted'):
        plt.scatter(y_true, y_pred)
        plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], color='red')
        plt.xlabel('Actual G_SC')
        plt.ylabel('Predicted G_SC')
        plt.title(title)
        plt.show()

    def plot_residuals(self, residuals, title='Residuals Distribution'):
        plt.hist(residuals, bins=30)
        plt.xlabel('Residuals')
        plt.ylabel('Frequency')
        plt.title(title)
        plt.show()

# %%
class EnhancedPerformancePredictor:
    def __init__(self, df):
        self.df = df.copy()
        self.model = MultipleLinearRegression()
        self.evaluator = ModelEvaluator()
        self.academic_features = [
            top_academic[0],
            top_academic[1],
            top_academic[2],
            top_academic[3],
            top_academic[4],
            top_academic[5]
        ]
        self.socioeconomic_features = [
            top_socioeconomic[0],
            top_socioeconomic[1],
            top_socioeconomic[2],
            top_socioeconomic[3],
            top_socioeconomic[4],
            top_socioeconomic[5]
        ]
    
    def preprocess(self):
        # No missing values, minimal preprocessing needed
        pass

    def train_and_evaluate(self, features):
        X = self.df[features].values
        y = self.df['G_SC'].values

        # Train-test split manually (80% train, 20% test)
        n = len(X)
        split_idx = int(0.8 * n)
        X_train, X_test = X[:split_idx], X[split_idx:]
        y_train, y_test = y[:split_idx], y[split_idx:]

        self.model.fit(X_train, y_train)
        y_pred = self.model.predict(X_test)

        mse = self.evaluator.mean_squared_error(y_test, y_pred)
        r2 = self.evaluator.r2_score(y_test, y_pred)

        print(f"Features used: {features}")
        print(f"Test MSE: {mse:.4f}")
        print(f"Test R²: {r2:.4f}")

        self.evaluator.plot_predictions(y_test, y_pred, title=f'Actual vs Predicted ({features})')
        residuals = y_test - y_pred
        self.evaluator.plot_residuals(residuals, title=f'Residuals ({features})')

        return r2  # Important for comparison

# %%
# Drop any rows with NaN values before creating the predictor
df_clean = df.dropna()

predictor = EnhancedPerformancePredictor(df_clean)

predictor.preprocess()

print("------- Academic Factors -------")
r2_academic = predictor.train_and_evaluate(predictor.academic_features)

print("\n------- Socioeconomic Factors -------")
r2_socioeconomic = predictor.train_and_evaluate(predictor.socioeconomic_features)

# Compare
if r2_academic > r2_socioeconomic:
    print("\n🎯 Academic factors explain G_SC better.")
    print(f"R² Academic: {r2_academic:.4f} vs R² Socioeconomic: {r2_socioeconomic:.4f}")
else:
    print("\n🎯 Socioeconomic factors explain G_SC better.")
    print(f"R² Socioeconomic: {r2_socioeconomic:.4f} vs R² Academic: {r2_academic:.4f}")
# Out:
# ------- Academic Factors -------
# Features used: ['Critical Reading_PRO', 'Citizen Competencies_PRO', 'English_PRO', 'Quantitative Reasoning_PRO', 'Biology_S11', 'English_S11']
# Test MSE: 79.1001
# Test R²: 0.8618
# ------- Socioeconomic Factors -------
# Features used: ['UNIVERSITY_ENCODED', 'Revenue', 'STRATUM_NUMERICAL', 'EDU_FATHER_ENCODED', 'EDU_MOTHER_ENCODED', 'SCHOOL_NAT_PUBLIC']
# Test MSE: 299.7391
# Test R²: 0.4763
# 🎯 Academic factors explain G_SC better.
# R² Academic: 0.8618 vs R² Socioeconomic: 0.4763
